# %% [markdown]
# # Function 3: 3D Drug Discovery
#
# *Analogy: **Minimize** side effects. The portal returns $y$ values that are all negative; **higher** (less negative, closer to 0) = fewer side effects = **better**. We **maximise** $y$ directly — no sign flip needed — which is equivalent to minimising side effects.*
#
# ### Characteristics
#
# * **3D input**: $(x_1, x_2, x_3)$ — e.g. drug formulation or dose parameters in $[0,1]^3$.
#
# * **Objective**: Maximise $y$ (all values are negative; the best outcome is the least negative). Initial data: 15 points, shape (15, 3).
#
# * **Strategy**: Same Bayesian optimisation workflow — GP surrogate, EI/PI/UCB acquisition — in 3D; visualisation uses 2D pairwise slices.

# %% [markdown]
# ## 1. Setup and load data (read-only from initial_data)

# %%
import sys, copy
import numpy as np
from pathlib import Path
from scipy.stats import norm
import matplotlib.pyplot as plt
from matplotlib import cm

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel, WhiteKernel
from skopt.acquisition import gaussian_ei, gaussian_pi, gaussian_lcb
from skopt.sampler import Lhs, Sobol

repo_root = Path.cwd() if (Path.cwd() / "src").exists() else Path.cwd().parent
sys.path.insert(0, str(repo_root))
from src.utils.load_challenge_data import (
    load_function_data, load_problem_data_csv, assert_not_under_initial_data,
)
from src.utils.warping import apply_output_warping
from src.utils.plot_utilities import (
    prepare_surface_for_plot as _prepare_surface_for_plot,
    setup_matplotlib,
)

setup_matplotlib()

# Figure sizes (inches) — consistent across this notebook
F3_FIG_1X2 = (12.0, 5.0)
F3_FIG_1X2_LINE = (12.0, 4.5)
F3_FIG_1X3 = (16.0, 5.0)
F3_FIG_3X2 = (12.0, 14.0)

np.random.seed(42)

# %%
local_dir       = repo_root / "data" / "problems" / "function_3"
csv_path        = local_dir / "observations.csv"
PLOT_EXPORT_DIR = repo_root / "data" / "results" / "function_3"

# %%
try:
    _ = OUTPUT_WARPING
except NameError:
    OUTPUT_WARPING = None  # set in params cell; default when run before params
if csv_path.exists():
    X, y = load_problem_data_csv(csv_path)
else:
    X, y = load_function_data(function_id=3)
    y = np.asarray(y, dtype=np.float64).ravel()
y_orig = np.asarray(y, dtype=np.float64).copy()
y, warp_params, _msg = apply_output_warping(y_orig, mode=OUTPUT_WARPING)
print(_msg)
WARP_LABEL = (warp_params[0] if warp_params else "None")
best_idx  = np.argmax(y)
best_y    = y[best_idx]
best_x_so_far = X[best_idx]

print(f"Loaded {len(y)} obs  |  X {X.shape}  |  best y = {best_y:.4g}  "
      f"at ({best_x_so_far[0]:.4f}, {best_x_so_far[1]:.4f}, {best_x_so_far[2]:.4f})")
# Out:
# Output warping: None. GP fits raw y. No transform applied.
# Loaded 25 obs  |  X (25, 3)  |  best y = -0.01886  at (0.4377, 0.3980, 0.4446)

# %%
CONSTANT_KERNEL_SCALE = 1.0    # output-scale; normalized y so value matters little
LENGTH_SCALE          = 1.0    # init length-scale; sklearn optimizes this — lower = wigglier
GP_ALPHA              = 1e-6   # nugget for numerical stability; raise to 1e-4 if Cholesky fails
MATERN_NU             = 1.5    # roughness: 0.5=exp, 1.5=C¹, 2.5=C², ∞=RBF
WHITE_NOISE_LEVEL     = 1e-5   # noise init; raise to 0.01-0.1 if oracle is stochastic
GP_KERNEL             = None   # Option to pass: None or "none" → LML auto-select; "RBF" | "Matern" | "RBF + WhiteKernel" → use that kernel

OPTIMIZE_KERNEL       = True   # Optimize kernel hyperparameters (if True use best kernel)
N_RESTARTS_KERNEL     = 15      # 3D: scale restarts with dimension
CONSTANT_SCALE_BOUNDS = (1e-3, 1e3)  # bounds for ConstantKernel output-scale
LENGTH_SCALE_BOUNDS   = (1e-2, 100)  # optimizer bounds; raise lower bound (e.g. 0.01) to avoid degenerate short-range kernels on noisy data
WHITE_NOISE_BOUNDS    = (1e-12, 1e1)  # bounds for WhiteKernel noise level

# ==== Output warping (HEBO-inspired) ====
OUTPUT_WARPING = None   # None | "boxcox" | "log" — transform y before GP fit; acquisition/next_x in warped space

XI_EI_PI  = 0.01     # ξ for EI/PI: 0.01-0.05 = exploit, 0.1-0.25 = explore (scale relative to y range ~0.4)
KAPPA_UCB = 1.0      # κ for UCB:   1-2 = exploit near mean peak, 3-5 = explore high-σ regions

n_grid_viz = 60        # coarser grid for Section 2 visualisation (scatter + IDW contours)
n_cand     = 2**15 # finer: number of candidates for acquisition maximisation (EI/PI/UCB)
CANDIDATE_SAMPLING_METHOD = "sobol"  #  'lhs' | 'sobol'

USE_ENSEMBLE    = False   # Set False to use SOLO_STRATEGY only
SOLO_STRATEGY   = "PI" # Used when USE_ENSEMBLE=False: "EI" | "PI" | "UCB"
AGREE_THRESHOLD = 0.05  # max pairwise L2 dist; if exceeded, use centroid
MIN_DIST_THRESHOLD = 0.05  # min L2 distance from any obs; mask acquisition at closer candidates
BOUNDARY_MARGIN = 0.05     # 0=off. Mask candidates near edges; low-d only; high-d use 0

# %%
IF_SHOW_PLOT      = True   # call plt.show() after each figure
IF_EXPORT_PLOT    = False  # save figures to PLOT_EXPORT_DIR
IF_EXPORT_QUERIES = True   # write next_x to data/submissions/
IF_APPEND_DATA    = False  # append new observation to observations.csv

CONTOURF_LEVELS     = 30    # number of filled contour levels (contourf)
CONTOUR_LINE_LEVELS = 11    # number of contour line levels (contour overlay)
CONTOUR_LINEWIDTH   = 1.0   # linewidth for contour() overlay
CONTOUR_LINESTYLE   = "-"   # linestyle: "-" | "--" | ":"
CONTOUR_ALPHA       = 0.5   # alpha for contour lines
SCATTER_EDGE_LW     = 1.5   # scatter marker edge linewidth
LEGEND_FONTSIZE     = 9
LEGEND_LOC          = "upper right"
LEGEND_FRAMEALPHA   = 0.95
LEGEND_NCOL         = 7     # columns for shared legend (Section 5)

print('Control flags set')
# Out:
# Control flags set

# %%
############################################
# SELECT OPTIMIZATION ALGORITHM SOLUTION EXPORT #
############################################
# Which solver's suggestion to save to data/submissions/function_3/.
# Options: 'MyBO' | 'Optuna-TPE' | 'Optuna-GP' | 'TuRBO' | 'DE-GP-EI'
NEXT_QUERY_SOLUTION = 'MyBO'

print(50*'=')
print(f'NEXT_QUERY_SOLUTION = {NEXT_QUERY_SOLUTION}')
print(50*'=')
# Out:
# ...
# NEXT_QUERY_SOLUTION = MyBO
# ...

# %% [markdown]
# ### Progress
# Left: y per query. Right: best y so far (cumulative max).

# %%
n_obs = len(y)
obs_idx = np.arange(1, n_obs + 1, dtype=float)
best_so_far = np.maximum.accumulate(y)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=F3_FIG_1X2_LINE)
ax1.plot(obs_idx, y, 'o-', color='blue', markersize=5, markerfacecolor='w', markeredgecolor='b', markeredgewidth=1.5, label=' y per query')
ax1.set_xlabel('Observation index')
ax1.set_ylabel('y')
ax1.set_title('Output y at each query')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.plot(obs_idx, best_so_far, 'o-', color='red', markersize=5, markerfacecolor='w', markeredgecolor='r', markeredgewidth=1.5, label='Best y so far')
ax2.set_xlabel('Observation index')
ax2.set_ylabel('Best y so far')
ax2.set_title('Cumulative best')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# ## 2. Visualize the points

# %%
_sampler = Sobol() if CANDIDATE_SAMPLING_METHOD == "sobol" else Lhs()
candidate_pts = np.array(_sampler.generate([(0.0, 1.0)] * 3, n_cand))
diff = candidate_pts[:, None, :] - X[None, :, :]  # (n_cand, n_obs, 3)
dists = np.sqrt((diff ** 2).sum(axis=2))
min_dist = np.min(dists, axis=1)  # (n_cand,)

fig2, axes = plt.subplots(1, 3, figsize=F3_FIG_1X3)
pairs = [(0, 1, r"$x_1$", r"$x_2$"), (0, 2, r"$x_1$", r"$x_3$"), (1, 2, r"$x_2$", r"$x_3$")]
for ax, (i, j, li, lj) in zip(axes, pairs):
    sc = ax.scatter(X[:, i], X[:, j], c=y, s=50, cmap="magma", edgecolors="k", linewidths=SCATTER_EDGE_LW)
    for idx in range(len(y)):
        ax.text(X[idx, i] + 0.02, X[idx, j] + 0.02, str(idx + 1), fontsize=8, zorder=10)
    ax.set_xlabel(li); ax.set_ylabel(lj); ax.set_title(f"{li} vs {lj}")
    ax.set_aspect("equal")
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
sm = plt.cm.ScalarMappable(norm=plt.Normalize(y.min(), y.max()), cmap="magma")
sm.set_array(y)
cbar = fig2.colorbar(sm, ax=axes.ravel().tolist(), location="right", shrink=0.8, label="y")

if IF_EXPORT_PLOT:
    out_dir = PLOT_EXPORT_DIR
    assert_not_under_initial_data(out_dir, project_root=repo_root)
    out_dir.mkdir(parents=True, exist_ok=True)
    out_path_2d = out_dir / "function_3_observations_2d_pairs.png"
    fig2.savefig(out_path_2d, dpi=150, format="png")
    print("Plot saved to", out_path_2d)
if IF_SHOW_PLOT:
    plt.show()

n_idw = n_grid_viz
ug_idw = np.linspace(0, 1, n_idw)
Ug_idw, Vg_idw = np.meshgrid(ug_idw, ug_idw)

Y_idw_all = []
for (i, j, li, lj) in pairs:
    grid_2d = np.column_stack([Ug_idw.ravel(), Vg_idw.ravel()])
    obs_2d  = np.column_stack([X[:, i], X[:, j]])
    dist_gx = np.sqrt(((grid_2d[:, None, :] - obs_2d[None, :, :]) ** 2).sum(axis=2)) + 1e-12
    w = 1.0 / (dist_gx ** 2)
    Y_idw_all.append(((w * y[None, :]).sum(axis=1) / w.sum(axis=1)).reshape(Ug_idw.shape))
_idw_min = min(np.nanmin(s) for s in Y_idw_all)
_idw_max = max(np.nanmax(s) for s in Y_idw_all)
if _idw_max <= _idw_min: _idw_max = _idw_min + 1e-10
_idw_levels = np.linspace(_idw_min, _idw_max, CONTOURF_LEVELS)

fig3, axes3 = plt.subplots(1, 3, figsize=F3_FIG_1X3)
for ax, (i, j, li, lj), Y_idw in zip(axes3, pairs, Y_idw_all):
    ax.contourf(Ug_idw, Vg_idw, Y_idw, levels=_idw_levels, cmap="magma")
    ax.contour(Ug_idw, Vg_idw, Y_idw, levels=_idw_levels[::max(1, len(_idw_levels)//CONTOUR_LINE_LEVELS)], colors="white", linewidths=CONTOUR_LINEWIDTH, linestyles='-', alpha=CONTOUR_ALPHA)
    ax.scatter(X[:, i], X[:, j], c='red', s=50, edgecolors="k", linewidths=SCATTER_EDGE_LW, zorder=2)
    for idx in range(len(y)):
        ax.text(X[idx, i] + 0.02, X[idx, j] + 0.02, str(idx + 1), fontsize=8, color="white", zorder=10)
    ax.set_xlabel(li); ax.set_ylabel(lj)
    ax.set_title(f"{li} vs {lj} (interpolated)")
    ax.set_aspect("equal")
    ax.set_xlim(0, 1); ax.set_ylim(0, 1)
sm3 = plt.cm.ScalarMappable(norm=plt.Normalize(_idw_min, _idw_max), cmap="magma")
sm3.set_array([])
cbar3 = fig3.colorbar(sm3, ax=axes3.ravel().tolist(), location="right", shrink=0.8, label="y", pad=0.02)

if IF_EXPORT_PLOT:
    out_path_idw = out_dir / "function_3_observations_2d_pairs_interpolated.png"
    fig3.savefig(out_path_idw, dpi=150, format="png", bbox_inches="tight")
    print("Plot saved to", out_path_idw)
if IF_SHOW_PLOT:
    plt.show()

# %% [markdown]
# ## 3. Suggest next point to submit, using Bayesian Optimization Methodology

# %% [markdown]
# ### 3.1 Surrogate: GP kernels
#
#  * **Gaussian Process (GP)** — we compare three kernel choices below; each gives a different prior over functions and uncertainty:

# %%
_gp_optimizer = None if not OPTIMIZE_KERNEL else 'fmin_l_bfgs_b'
_gp_n_restarts = N_RESTARTS_KERNEL if OPTIMIZE_KERNEL else 0
kernel_RBF       = ConstantKernel(CONSTANT_KERNEL_SCALE, constant_value_bounds=CONSTANT_SCALE_BOUNDS) * RBF(length_scale=LENGTH_SCALE, length_scale_bounds=LENGTH_SCALE_BOUNDS)
kernel_Matern    = ConstantKernel(CONSTANT_KERNEL_SCALE, constant_value_bounds=CONSTANT_SCALE_BOUNDS) * Matern(length_scale=LENGTH_SCALE, nu=MATERN_NU, length_scale_bounds=LENGTH_SCALE_BOUNDS)
kernel_RBF_noise = ConstantKernel(CONSTANT_KERNEL_SCALE, constant_value_bounds=CONSTANT_SCALE_BOUNDS) * RBF(length_scale=LENGTH_SCALE, length_scale_bounds=LENGTH_SCALE_BOUNDS) + WhiteKernel(noise_level=WHITE_NOISE_LEVEL, noise_level_bounds=WHITE_NOISE_BOUNDS)
gp_RBF       = GaussianProcessRegressor(kernel=kernel_RBF,       alpha=GP_ALPHA, optimizer=_gp_optimizer, n_restarts_optimizer=_gp_n_restarts, normalize_y=True)
gp_Matern    = GaussianProcessRegressor(kernel=kernel_Matern,    alpha=GP_ALPHA, optimizer=_gp_optimizer, n_restarts_optimizer=_gp_n_restarts, normalize_y=True)
gp_RBF_noise = GaussianProcessRegressor(kernel=kernel_RBF_noise, alpha=GP_ALPHA, optimizer=_gp_optimizer, n_restarts_optimizer=_gp_n_restarts, normalize_y=True)
gp_RBF.fit(X, y); gp_Matern.fit(X, y); gp_RBF_noise.fit(X, y)
print(f"Kernel hyperparameters: {'optimized (MLE)' if OPTIMIZE_KERNEL else 'fixed (no optimization)'}")
mu_cand_RBF, sigma_cand_RBF = gp_RBF.predict(candidate_pts, return_std=True)
mu_cand_Matern, sigma_cand_Matern = gp_Matern.predict(candidate_pts, return_std=True)
mu_cand_RBF_noise, sigma_cand_RBF_noise = gp_RBF_noise.predict(candidate_pts, return_std=True)
gp_neg_RBF = copy.deepcopy(gp_RBF); gp_neg_Matern = copy.deepcopy(gp_Matern); gp_neg_RBF_noise = copy.deepcopy(gp_RBF_noise)
gp_neg_RBF.fit(X, -y); gp_neg_Matern.fit(X, -y); gp_neg_RBF_noise.fit(X, -y)
print("GP RBF:", gp_RBF.kernel_)
# Out:
# Kernel hyperparameters: optimized (MLE)
# GP RBF: 1.03**2 * RBF(length_scale=0.262)

# %%
gps = [
    (gp_RBF,       gp_neg_RBF,       "RBF"),
    (gp_Matern,    gp_neg_Matern,    "Matérn (ν=1.5)"),
    (gp_RBF_noise, gp_neg_RBF_noise, "RBF + WhiteKernel"),
]
CANONICAL_NAMES = ["RBF", "Matérn (ν=1.5)", "RBF + WhiteKernel"]
KERNEL_ALIASES = {
    "rbf": "RBF",
    "matern": "Matérn (ν=1.5)",
    "matérn (ν=1.5)": "Matérn (ν=1.5)",
    "matern (ν=1.5)": "Matérn (ν=1.5)",
    "rbf + whitekernel": "RBF + WhiteKernel",
    "rbf+whitekernel": "RBF + WhiteKernel",
    "rbf + white": "RBF + WhiteKernel",
    "white": "RBF + WhiteKernel",
}

def _normalize_kernel_input(val):
    if val is None:
        return None
    s = str(val).strip()
    if s.lower() in ("none", ""):
        return None
    return s

def _resolve_kernel_name(user_input):
    if user_input is None:
        return None
    key = user_input.lower().strip()
    if key in KERNEL_ALIASES:
        return KERNEL_ALIASES[key]
    if user_input in CANONICAL_NAMES:
        return user_input
    for c in CANONICAL_NAMES:
        if c.lower() == key or key in c.lower():
            return c
    return None

use_lml = _normalize_kernel_input(GP_KERNEL) is None

if use_lml:
    print(75*'=')
    print('Kernel selection via log-marginal-likelihood (LML)')
    print(75*'=')
    lml_scores = {name: gp.log_marginal_likelihood_value_ for gp, _, name in gps}
    best_name = max(lml_scores, key=lml_scores.get)
    print('Log-marginal-likelihood per kernel:')
    for name, score in lml_scores.items():
        flag = '  ← best' if name == best_name else ''
        print(f'  {name:22s}: {score:.4f}{flag}')
    print(f'\nAuto-selected kernel: {best_name}')
else:
    resolved = _resolve_kernel_name(_normalize_kernel_input(GP_KERNEL))
    if resolved is None:
        print(f"Unknown kernel '{GP_KERNEL}'. Choose from: {CANONICAL_NAMES}. Falling back to LML.")
        lml_scores = {name: gp.log_marginal_likelihood_value_ for gp, _, name in gps}
        best_name = max(lml_scores, key=lml_scores.get)
    else:
        best_name = resolved
        print(f'Manual kernel selection: {best_name}')

best_gp     = next(g  for g, _, n in gps if n == best_name)
best_gp_neg = next(gn for _, gn, n in gps if n == best_name)
is_rbf    = (best_name == 'RBF')
is_matern = ('Matérn' in best_name)
is_rbf_w  = (best_name == 'RBF + WhiteKernel')
print(f'  Fitted kernel: {best_gp.kernel_}')
print(75*'=')
# Out:
# ...
# Kernel selection via log-marginal-likelihood (LML)
# ...
# Log-marginal-likelihood per kernel:
#   RBF                   : -26.4705
#   Matérn (ν=1.5)        : -26.1040  ← best
#   RBF + WhiteKernel     : -26.2639
#
# Auto-selected kernel: Matérn (ν=1.5)
#   Fitted kernel: 1.48**2 * Matern(length_scale=0.624, nu=1.5)
# ...

# %%
n_slice = 50
ug = np.linspace(0, 1, n_slice)
Ug, Vg = np.meshgrid(ug, ug)
med = [np.median(X[:, k]) for k in range(3)]
slices_info = [
    (np.column_stack([Ug.ravel(), Vg.ravel(), np.full(Ug.size, med[2])]), Ug, Vg, 0, 1, r"$x_1$", r"$x_2$", fr"$x_3$ = {med[2]:.2f}"),
    (np.column_stack([Ug.ravel(), np.full(Ug.size, med[1]), Vg.ravel()]), Ug, Vg, 0, 2, r"$x_1$", r"$x_3$", fr"$x_2$ = {med[1]:.2f}"),
    (np.column_stack([np.full(Ug.size, med[0]), Ug.ravel(), Vg.ravel()]), Ug, Vg, 1, 2, r"$x_2$", r"$x_3$", fr"$x_1$ = {med[0]:.2f}"),
]
fig, axes = plt.subplots(3, 2, figsize=F3_FIG_3X2)
for row, (slice_pts, Ag, Bg, ia, ib, la, lb, slice_label) in enumerate(slices_info):
    mu_slice, sigma_slice = best_gp.predict(slice_pts, return_std=True)
    mu_slice = mu_slice.reshape(Ug.shape); sigma_slice = sigma_slice.reshape(Ug.shape)
    ax_mu, ax_sig = axes[row, 0], axes[row, 1]
    _mu_min, _mu_max = np.nanmin(mu_slice), np.nanmax(mu_slice)
    _sig_min, _sig_max = np.nanmin(sigma_slice), np.nanmax(sigma_slice)
    if _mu_max <= _mu_min: _mu_max = _mu_min + 1e-10
    if _sig_max <= _sig_min: _sig_max = _sig_min + 1e-10
    levels_mu = np.linspace(_mu_min, _mu_max, CONTOURF_LEVELS)
    levels_sig = np.linspace(_sig_min, _sig_max, CONTOURF_LEVELS)
    cf1 = ax_mu.contourf(Ag, Bg, mu_slice, levels=levels_mu, cmap="viridis")
    ax_mu.contour(Ag, Bg, mu_slice, levels=np.linspace(_mu_min, _mu_max, CONTOUR_LINE_LEVELS), colors="k", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig.colorbar(cf1, ax=ax_mu).set_label("μ(x)")
    ax_mu.scatter(X[:, ia], X[:, ib], c="red", s=80, edgecolors="k", zorder=2, linewidths=1.5)
    ax_mu.set_xlabel(la); ax_mu.set_ylabel(lb)
    ax_mu.set_title(f"{best_name} — mean ({slice_label})")
    ax_mu.set_aspect("equal")
    cf2 = ax_sig.contourf(Ag, Bg, sigma_slice, levels=levels_sig, cmap="plasma")
    ax_sig.contour(Ag, Bg, sigma_slice, levels=np.linspace(_sig_min, _sig_max, CONTOUR_LINE_LEVELS), colors="b", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig.colorbar(cf2, ax=ax_sig).set_label("σ(x)")
    ax_sig.scatter(X[:, ia], X[:, ib], c="red", s=80, edgecolors="k", zorder=2, linewidths=1.5)
    ax_sig.set_xlabel(la); ax_sig.set_ylabel(lb)
    ax_sig.set_title(f"{best_name} — std ({slice_label})")
    ax_sig.set_aspect("equal")
fig.suptitle(f"GP surrogate: posterior mean and uncertainty (σ)  |  warping: {WARP_LABEL}", y=0.995)
if IF_EXPORT_PLOT:
    out_dir = PLOT_EXPORT_DIR
    assert_not_under_initial_data(out_dir, project_root=repo_root)
    out_dir.mkdir(parents=True, exist_ok=True)
    fig.savefig(out_dir / "function_3_gp_slices.png", dpi=150, bbox_inches="tight")
if IF_SHOW_PLOT: plt.show()

# %% [markdown]
# ### 3.2 Acquisition functions
#
# * Expected Improvement (EI)
#
# * Upper Confidence Bound (UCB)
#
# * Probability of Improvement (PI)

# %%
y_best = best_y

EI_RBF  = gaussian_ei(candidate_pts, gp_neg_RBF, y_opt=-y_best, xi=XI_EI_PI)
PI_RBF  = gaussian_pi(candidate_pts, gp_neg_RBF, y_opt=-y_best, xi=XI_EI_PI)
LCB_RBF = gaussian_lcb(candidate_pts, gp_neg_RBF, kappa=KAPPA_UCB)

EI_Matern  = gaussian_ei(candidate_pts, gp_neg_Matern, y_opt=-y_best, xi=XI_EI_PI)
PI_Matern  = gaussian_pi(candidate_pts, gp_neg_Matern, y_opt=-y_best, xi=XI_EI_PI)
LCB_Matern = gaussian_lcb(candidate_pts, gp_neg_Matern, kappa=KAPPA_UCB)

EI_RBF_noise  = gaussian_ei(candidate_pts, gp_neg_RBF_noise, y_opt=-y_best, xi=XI_EI_PI)
PI_RBF_noise  = gaussian_pi(candidate_pts, gp_neg_RBF_noise, y_opt=-y_best, xi=XI_EI_PI)
LCB_RBF_noise = gaussian_lcb(candidate_pts, gp_neg_RBF_noise, kappa=KAPPA_UCB)

# Mask candidates too close to existing observations (avoid re-evaluating)
min_dist_cand = np.min(np.sqrt(((candidate_pts[:, None, :] - X[None, :, :]) ** 2).sum(axis=2)), axis=1)
next_x_high_dist = np.clip(np.asarray(candidate_pts[np.argmax(min_dist_cand)]).ravel(), 0.0, 0.999999)
too_close = min_dist_cand < MIN_DIST_THRESHOLD
try: BOUNDARY_MARGIN
except NameError: BOUNDARY_MARGIN = 0
# Optional: mask candidates near domain boundaries (low-d only; set BOUNDARY_MARGIN=0 for high-d)
near_boundary = np.any((candidate_pts <= BOUNDARY_MARGIN) | (candidate_pts >= 1.0 - BOUNDARY_MARGIN), axis=1) if BOUNDARY_MARGIN > 0 else np.zeros(len(candidate_pts), dtype=bool)
masked = too_close | near_boundary
EI_RBF[masked] = EI_Matern[masked] = EI_RBF_noise[masked] = -np.inf
PI_RBF[masked] = PI_Matern[masked] = PI_RBF_noise[masked] = -np.inf
LCB_RBF[masked] = LCB_Matern[masked] = LCB_RBF_noise[masked] = np.inf

def _pick(acq_val, maximize, fallback):
    idx = np.argmax(acq_val) if maximize else np.argmin(acq_val)
    return np.asarray(fallback).ravel() if masked[idx] else candidate_pts[idx]

x_best_EI_RBF  = _pick(EI_RBF, True, next_x_high_dist)
x_best_PI_RBF  = _pick(PI_RBF, True, next_x_high_dist)
x_best_UCB_RBF = _pick(LCB_RBF, False, next_x_high_dist)
x_best_EI_Matern  = _pick(EI_Matern, True, next_x_high_dist)
x_best_PI_Matern  = _pick(PI_Matern, True, next_x_high_dist)
x_best_UCB_Matern = _pick(LCB_Matern, False, next_x_high_dist)
x_best_EI_RBF_noise  = _pick(EI_RBF_noise, True, next_x_high_dist)
x_best_PI_RBF_noise  = _pick(PI_RBF_noise, True, next_x_high_dist)
x_best_UCB_RBF_noise = _pick(LCB_RBF_noise, False, next_x_high_dist)

x_best_EI  = x_best_EI_RBF  if is_rbf else (x_best_EI_Matern  if is_matern else x_best_EI_RBF_noise)
x_best_PI  = x_best_PI_RBF  if is_rbf else (x_best_PI_Matern  if is_matern else x_best_PI_RBF_noise)
x_best_UCB = x_best_UCB_RBF if is_rbf else (x_best_UCB_Matern if is_matern else x_best_UCB_RBF_noise)

print(f"Best kernel: {best_name}")
print(f"  EI  argmax: ({x_best_EI[0]:.4f}, {x_best_EI[1]:.4f}, {x_best_EI[2]:.4f})")
print(f"  PI  argmax: ({x_best_PI[0]:.4f}, {x_best_PI[1]:.4f}, {x_best_PI[2]:.4f})")
print(f"  UCB argmax: ({x_best_UCB[0]:.4f}, {x_best_UCB[1]:.4f}, {x_best_UCB[2]:.4f})")
# Out:
# Best kernel: Matérn (ν=1.5)
#   EI  argmax: (0.9465, 0.9435, 0.3765)
#   PI  argmax: (0.3244, 0.3771, 0.4782)
#   UCB argmax: (0.9465, 0.9435, 0.3765)

# %%
############################################################
# Acquisition: candidate pool (pairwise projections of evaluation points)
############################################################

_cand_xyz = np.asarray(candidate_pts, dtype=float).reshape(-1, 3)
_n_pool = len(_cand_xyz)
pairs_cand = [(0, 1, r"$x_1$", r"$x_2$"), (0, 2, r"$x_1$", r"$x_3$"), (1, 2, r"$x_2$", r"$x_3$")]

fig_cand, axes_cand = plt.subplots(1, 3, figsize=F3_FIG_1X3)
for _axi, (ax_c, (i, j, li, lj)) in enumerate(zip(axes_cand, pairs_cand)):
    _kw = dict(label=f"Candidate evals (n = {_n_pool:,})") if _axi == 0 else {}
    ax_c.scatter(
        _cand_xyz[:, i], _cand_xyz[:, j],
        s=2, c="#4a90c8", alpha=0.35, linewidths=0, rasterized=True,
        **_kw,
    )
    ax_c.scatter(X[:, i], X[:, j], c="white", s=35, edgecolors="red", zorder=6, linewidths=1.0, label="Observations")
    ax_c.scatter(best_x_so_far[i], best_x_so_far[j], s=180, marker="+", c="blue", linewidths=1.5, zorder=7, label="Best obs")
    ax_c.set_xlim(0, 1)
    ax_c.set_ylim(0, 1)
    ax_c.set_aspect("equal")
    ax_c.set_xlabel(li); ax_c.set_ylabel(lj)
    ax_c.set_title(f"Evaluations in ({li}, {lj}) plane")
    ax_c.legend(loc="upper right", framealpha=0.95)
fig_cand.suptitle(
    f"Where acquisition is evaluated  |  {CANDIDATE_SAMPLING_METHOD}  |  kernel: {best_name}"
)
if IF_EXPORT_PLOT:
    out_dir = PLOT_EXPORT_DIR
    assert_not_under_initial_data(out_dir, project_root=repo_root)
    out_dir.mkdir(parents=True, exist_ok=True)
    fig_cand.savefig(out_dir / "function_3_acquisition_candidate_pool.png", dpi=150, bbox_inches="tight")
if IF_SHOW_PLOT:
    plt.show()

# %%
rng = np.random.default_rng(42)
best_x = best_x_so_far.copy()
next_x_exploit = np.clip(best_x + rng.uniform(-0.1, 0.1, size=3), 0, 1)
next_x_explore = rng.uniform(0, 1, size=3)
print("Exploit:  ", next_x_exploit)
print("Explore:  ", next_x_explore)
# Out:
# Exploit:   [0.49247221 0.38578569 0.51632958]
# Explore:   [0.69736803 0.09417735 0.97562235]

# %% [markdown]
# ### 3.3 Acquisition function surfaces
# We evaluate EI/PI/UCB on `candidate_pts` (no 2D contour); Section 4 shows the suggested next points (EI, PI, UCB) via 2D pairwise projections.

# %% [markdown]
# ### Pairwise distances between suggestions (small = agree)
# Small values mean two strategies agree; large values mean they point to different regions.

# %%
names = ['EI', 'UCB', 'PI']
pts = [np.asarray(x).ravel() for x in [x_best_EI, x_best_UCB, x_best_PI]]
n_pts = len(pts)
dists = np.zeros((n_pts, n_pts))
for i in range(n_pts):
    for j in range(n_pts):
        dists[i, j] = np.linalg.norm(pts[i] - pts[j])
for i in range(n_pts):
    for j in range(i + 1, n_pts):
        print(f"  {names[i]} vs {names[j]}: {dists[i, j]:.4f}")
max_d_3 = max(np.linalg.norm(pts[0]-pts[1]), np.linalg.norm(pts[0]-pts[2]), np.linalg.norm(pts[1]-pts[2]))
if max_d_3 < AGREE_THRESHOLD:
    print(f"\n>>> EI/PI/UCB agree (max pairwise dist = {max_d_3:.4f} < {AGREE_THRESHOLD}).")
else:
    print(f"\n>>> EI/PI/UCB differ (max dist = {max_d_3:.4f}); ensemble would use centroid.")
# Out:
#   EI vs UCB: 0.0000
#   EI vs PI: 0.8474
#   UCB vs PI: 0.8474
#
# >>> EI/PI/UCB differ (max dist = 0.8474); ensemble would use centroid.

# %% [markdown]
# ## 4. Select next query
#
# Ensemble: EI, PI, UCB agree → use EI; disagree → use centroid. See `docs_private/40_notes_and_references/00_bayesian_methods/ensemble_acquisition_guide.md`.

# %%
x_EI  = np.asarray(x_best_EI).ravel()
x_PI  = np.asarray(x_best_PI).ravel()
x_UCB = np.asarray(x_best_UCB).ravel()
pts = np.array([x_EI, x_PI, x_UCB])
d12 = np.linalg.norm(pts[0] - pts[1])
d13 = np.linalg.norm(pts[0] - pts[2])
d23 = np.linalg.norm(pts[1] - pts[2])
max_d = max(d12, d13, d23)

_solo_map = {"EI": x_EI, "PI": x_PI, "UCB": x_UCB}
next_x_no_ens = np.clip(_solo_map.get(SOLO_STRATEGY, x_EI).copy(), 0.0, 0.999999)
next_x_with_ens = np.clip(np.mean(pts, axis=0), 0.0, 0.999999) if max_d >= AGREE_THRESHOLD else np.clip(x_EI.copy(), 0.0, 0.999999)

print(f"Without ensemble ({SOLO_STRATEGY}):  x = ({next_x_no_ens[0]:.4f}, {next_x_no_ens[1]:.4f}, {next_x_no_ens[2]:.4f})")
print(f"With ensemble: EI=({x_EI[0]:.4f},{x_EI[1]:.4f},{x_EI[2]:.4f}), PI=({x_PI[0]:.4f},{x_PI[1]:.4f},{x_PI[2]:.4f}), UCB=({x_UCB[0]:.4f},{x_UCB[1]:.4f},{x_UCB[2]:.4f}) → max_dist={max_d:.4f}")
print(f"  → {'centroid' if max_d >= AGREE_THRESHOLD else 'all agree, EI'} = ({next_x_with_ens[0]:.4f}, {next_x_with_ens[1]:.4f}, {next_x_with_ens[2]:.4f})")

next_x = next_x_with_ens if USE_ENSEMBLE else next_x_no_ens

# Proximity check: only replace with fallback for near-duplicates.
DUPLICATE_THRESHOLD = 1e-3
dist_to_obs = np.sqrt(((X - next_x) ** 2).sum(axis=1))
nearest_idx  = np.argmin(dist_to_obs)
nearest_dist = dist_to_obs[nearest_idx]
if nearest_dist < DUPLICATE_THRESHOLD:
    print(f"⚠ Proposed point is duplicate (dist={nearest_dist:.2e} to obs #{nearest_idx+1}); using high-dist fallback.")
    next_x = next_x_high_dist
elif nearest_dist < MIN_DIST_THRESHOLD:
    print(f"  (Proposed point is {nearest_dist:.4f} from obs #{nearest_idx+1} — keeping it.)")

_strat = 'ensemble' if USE_ENSEMBLE else SOLO_STRATEGY
print(f"Next query | kernel: {best_name} | strategy: {_strat} | xi={XI_EI_PI}")
print(f"  x = ({next_x[0]:.4f}, {next_x[1]:.4f}, {next_x[2]:.4f})")
print(f"  Nearest existing obs: #{nearest_idx+1} at dist={nearest_dist:.4f}")
print(f"  Current best y = {best_y:.4g} at ({best_x_so_far[0]:.4f}, {best_x_so_far[1]:.4f}, {best_x_so_far[2]:.4f})")
# Out:
# Without ensemble (PI):  x = (0.3244, 0.3771, 0.4782)
# With ensemble: EI=(0.9465,0.9435,0.3765), PI=(0.3244,0.3771,0.4782), UCB=(0.9465,0.9435,0.3765) → max_dist=0.8474
#   → centroid = (0.7391, 0.7547, 0.4104)
# Next query | kernel: Matérn (ν=1.5) | strategy: PI | xi=0.01
#   x = (0.3244, 0.3771, 0.4782)
#   Nearest existing obs: #23 at dist=0.0903
#   Current best y = -0.01886 at (0.4377, 0.3980, 0.4446)

# %% [markdown]
# ## 5. Illustrate the locations on the proposed query

# %%
try:
    _ = next_x
except NameError:
    _ei = gaussian_ei(candidate_pts, best_gp_neg, y_opt=-y_best, xi=XI_EI_PI)
    next_x = np.clip(np.asarray(candidate_pts[np.argmax(_ei)]).ravel(), 0.0, 0.999999)

X_best_combined = np.array([x_best_EI, x_best_PI, x_best_UCB])
labels_combined = ['EI', 'PI', 'UCB']
colors_combined = plt.cm.cool(np.linspace(0, 1, len(X_best_combined)))
markers_size = [100, 150, 200]
next_x_plot = np.asarray(next_x).ravel()

n_acq_slice = 50
ug_acq = np.linspace(0, 1, n_acq_slice)
Ug_acq, Vg_acq = np.meshgrid(ug_acq, ug_acq)
med_acq = [np.median(X[:, k]) for k in range(3)]
slices_acq = [
    (np.column_stack([Ug_acq.ravel(), Vg_acq.ravel(), np.full(Ug_acq.size, med_acq[2])]), 0, 1, r"$x_1$", r"$x_2$", fr"$x_3$ = {med_acq[2]:.2f}"),
    (np.column_stack([Ug_acq.ravel(), np.full(Ug_acq.size, med_acq[1]), Vg_acq.ravel()]), 0, 2, r"$x_1$", r"$x_3$", fr"$x_2$ = {med_acq[1]:.2f}"),
    (np.column_stack([np.full(Ug_acq.size, med_acq[0]), Ug_acq.ravel(), Vg_acq.ravel()]), 1, 2, r"$x_2$", r"$x_3$", fr"$x_1$ = {med_acq[0]:.2f}"),
]

fig2, axes = plt.subplots(3, 2, figsize=F3_FIG_3X2)
for row, (slice_pts, ia, ib, la, lb, slice_label) in enumerate(slices_acq):
    mu_s, sig_s = best_gp.predict(slice_pts, return_std=True)
    mu_s = mu_s.reshape(Ug_acq.shape); sig_s = sig_s.reshape(Ug_acq.shape)
    ax_mu, ax_sig = axes[row, 0], axes[row, 1]

    _mu_min, _mu_max = np.nanmin(mu_s), np.nanmax(mu_s)
    if _mu_max <= _mu_min: _mu_max = _mu_min + 1e-10
    lev_mu = np.linspace(_mu_min, _mu_max, CONTOURF_LEVELS)
    cf1 = ax_mu.contourf(Ug_acq, Vg_acq, mu_s, levels=lev_mu, cmap="viridis")
    ax_mu.contour(Ug_acq, Vg_acq, mu_s, levels=np.linspace(_mu_min, _mu_max, CONTOUR_LINE_LEVELS),
                  colors="k", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig2.colorbar(cf1, ax=ax_mu).set_label("\u03bc(x)", fontsize=10)
    ax_mu.scatter(X[:, ia], X[:, ib], c="white", s=60, edgecolors="r", zorder=5, linewidths=1.5, label="Observations")
    ax_mu.scatter(best_x_so_far[ia], best_x_so_far[ib], s=500, marker="+", c="blue", linewidths=1.5, zorder=8, label="Best obs")
    for pt, lbl, col, size in zip(X_best_combined, labels_combined, colors_combined, markers_size):
        ax_mu.scatter(pt[ia], pt[ib], s=size, marker="s", c='none', edgecolors=[col], linewidths=2.0, alpha=0.95, zorder=10, label=lbl)
        ax_mu.annotate(lbl, (pt[ia], pt[ib]), xytext=(5, 5), textcoords="offset points", fontsize=9, zorder=11)
    ax_mu.scatter(next_x_plot[ia], next_x_plot[ib], facecolors="none", s=200, marker="s", edgecolors="red", linewidths=2, zorder=12, label="Proposed query")
    ax_mu.axvline(next_x_plot[ia], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_mu.axhline(next_x_plot[ib], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_mu.set_xlabel(la); ax_mu.set_ylabel(lb)
    ax_mu.set_title(f"Mean \u2014 {best_name} ({slice_label})", fontsize=11)
    ax_mu.set_aspect("equal"); ax_mu.set_xlim(0, 1); ax_mu.set_ylim(0, 1)

    _sig_min, _sig_max = np.nanmin(sig_s), np.nanmax(sig_s)
    if _sig_max <= _sig_min: _sig_max = _sig_min + 1e-10
    lev_sig = np.linspace(_sig_min, _sig_max, CONTOURF_LEVELS)
    cf2 = ax_sig.contourf(Ug_acq, Vg_acq, sig_s, levels=lev_sig, cmap="plasma")
    ax_sig.contour(Ug_acq, Vg_acq, sig_s, levels=np.linspace(_sig_min, _sig_max, CONTOUR_LINE_LEVELS),
                   colors="b", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig2.colorbar(cf2, ax=ax_sig).set_label("\u03c3(x)", fontsize=10)
    ax_sig.scatter(X[:, ia], X[:, ib], c="white", s=60, edgecolors="r", zorder=5, linewidths=1.5)
    ax_sig.scatter(best_x_so_far[ia], best_x_so_far[ib], s=500, marker="+", c="blue", linewidths=1.5, zorder=8)
    ax_sig.scatter(next_x_plot[ia], next_x_plot[ib], facecolors="none", s=200, marker="s", edgecolors="red", linewidths=2, zorder=12)
    ax_sig.axvline(next_x_plot[ia], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_sig.axhline(next_x_plot[ib], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_sig.set_xlabel(la); ax_sig.set_ylabel(lb)
    ax_sig.set_title(f"Std \u2014 {best_name} ({slice_label})", fontsize=11)
    ax_sig.set_aspect("equal"); ax_sig.set_xlim(0, 1); ax_sig.set_ylim(0, 1)

handles, lbls = axes[0, 0].get_legend_handles_labels()
fig2.legend(handles, lbls, loc="lower center", bbox_to_anchor=(0.5, -0.06),
            ncol=LEGEND_NCOL, frameon=True, framealpha=LEGEND_FRAMEALPHA)
_strat_label = ("ensemble \u2014 centroid" if (USE_ENSEMBLE and max_d >= AGREE_THRESHOLD)
                else "ensemble \u2014 EI (agreed)" if USE_ENSEMBLE
                else SOLO_STRATEGY)
fig2.suptitle(
    f"Proposed query: x = ({next_x[0]:.4f}, {next_x[1]:.4f}, {next_x[2]:.4f})  |  "
    f"kernel: {best_name}  |  strategy: {_strat_label}  |  warping: {WARP_LABEL}",
    y=1.02,
)

if IF_SHOW_PLOT:
    plt.show()
if IF_EXPORT_PLOT:
    out_dir = PLOT_EXPORT_DIR
    assert_not_under_initial_data(out_dir, project_root=repo_root)
    out_dir.mkdir(parents=True, exist_ok=True)
    out_path_2d = out_dir / "function_3_acquisition_points_2d_pairs.png"
    fig2.savefig(out_path_2d, dpi=150, format="png", bbox_inches="tight")
    print("Plot saved to", out_path_2d)

# %%
# Save next query: .npy for downstream code, .txt for the portal submission form
if IF_EXPORT_QUERIES:
    # Build solver registry: MyBO is always available; Optuna/TuRBO/DE-GP-EI require Section 6
    _solutions = {"MyBO": np.asarray(next_x).ravel()}
    try:
        _solutions.update({name: np.asarray(x_pt).ravel() for name, x_pt in suggestions})
    except NameError:
        pass  # Section 6 not yet run — only MyBO available

    if NEXT_QUERY_SOLUTION not in _solutions:
        print(f"\u26a0  NEXT_QUERY_SOLUTION='{NEXT_QUERY_SOLUTION}' not in {list(_solutions.keys())}; "
              f"run Section 6 first or change the flag. Falling back to MyBO.")
    _export_x = _solutions.get(NEXT_QUERY_SOLUTION, _solutions["MyBO"])

    next_x_clip = np.clip(np.asarray(_export_x, dtype=np.float64).ravel(), 0.0, 0.999999)
    portal_str = "-".join(f"{v:.6f}" for v in next_x_clip)
    out_dir = repo_root / "data" / "submissions" / "function_3"
    assert_not_under_initial_data(out_dir, project_root=repo_root)
    out_dir.mkdir(parents=True, exist_ok=True)
    np.save(out_dir / "next_input.npy", next_x_clip)
    (out_dir / "next_input_portal.txt").write_text(portal_str)
    print(f"Saved [{NEXT_QUERY_SOLUTION}]. Portal string: {portal_str}")
    print(f"  Available solvers: {list(_solutions.keys())}")
else:
    print("IF_EXPORT_QUERIES=False; not saved.")
# Out:
# Saved [MyBO]. Portal string: 0.437681-0.398010-0.444610
#   Available solvers: ['MyBO', 'Optuna-TPE', 'Optuna-GP', 'TuRBO', 'DE-GP-EI']

# %% [markdown]
# ## 6. MyBO vs Open Source Optimizers
#
# Compare **MyBO** (this notebook's EI/ensemble pipeline), **Optuna** (TPE/CMA-ES), **TuRBO**, and **DE-GP-EI** (DE on GP-EI) on the same data. Each solver suggests the next query; the summary figure shows 3 pairwise projections (x₁–x₂, x₁–x₃, x₂–x₃) with observations coloured by y and each solver's suggested point overlaid.

# %%
# MyBO = this notebook's next_x (Section 4). Optuna, TuRBO, DE-GP-EI = external solver wrappers.
# TuRBO requires BoTorch: pip install botorch (if you see "TuRBO skipped").
bounds_01 = [(0.0, 1.0)] * 3
suggestions = [("MyBO", np.asarray(next_x).ravel())]

def _try_suggest(name, mod_path, kwargs):
    try:
        mod = __import__(mod_path, fromlist=["suggest"])
        x_pt = np.asarray(mod.suggest(X, y, **kwargs)).ravel()
        return (name, x_pt)
    except Exception as e:
        print(f"{name} skipped — {e}")
        return None

for name, mod, kw in [
    ("Optuna-TPE", "src.optimizers.wrappers.optuna_solver", {"bounds": bounds_01, "function_id": 3, "seed": 42}),
    ("Optuna-GP",  "src.optimizers.wrappers.optuna_solver", {"bounds": bounds_01, "function_id": 3, "seed": 46, "sampler": "gp"}),
    ("TuRBO",  "src.optimizers.wrappers.turbo_solver",  {"bounds": bounds_01, "function_id": 3, "seed": 43}),
    ("DE-GP-EI",     "src.optimizers.wrappers.de_gp_ei_solver",     {"bounds": bounds_01, "function_id": 3, "seed": 44}),
]:
    r = _try_suggest(name, mod, kw)
    if r is not None:
        suggestions.append(r)

_SOLVER_STYLE = {
    "MyBO":   ("s", "red"),
    "Optuna-TPE": ("o", "blue"),
    "Optuna-GP":  ("o", "deepskyblue"),
    "TuRBO":  ("^", "green"),
    "DE-GP-EI":     ("D", "magenta"),
}
_FALLBACK_STYLES = [("P", "orange"), ("*", "cyan"), ("h", "lime")]

# 3-panel summary: pairwise scatter (x1-x2, x1-x3, x2-x3), observations + solver suggestions
pairs = [(0, 1, r"$x_1$", r"$x_2$"), (0, 2, r"$x_1$", r"$x_3$"), (1, 2, r"$x_2$", r"$x_3$")]
fig_s6, axes_s6 = plt.subplots(1, 3, figsize=F3_FIG_1X3)
_y_norm = plt.Normalize(float(np.min(y)), float(np.max(y)))
for ax, (i, j, li, lj) in zip(axes_s6, pairs):
    ax.scatter(X[:, i], X[:, j], c=y, s=50, cmap="magma", norm=_y_norm,
               edgecolors="gray", linewidths=SCATTER_EDGE_LW, zorder=5)
    ax.scatter(best_x_so_far[i], best_x_so_far[j], s=250, marker="+", c="blue", linewidths=2, zorder=8, label="Best obs")
    for idx, (name, x_pt) in enumerate(suggestions):
        mk, col = _SOLVER_STYLE.get(name, _FALLBACK_STYLES[min(idx, len(_FALLBACK_STYLES)-1)])
        if mk in ("x", "+"):
            ax.scatter(x_pt[i], x_pt[j], s=70, marker=mk, c=col, linewidths=2, zorder=12,
                       label=f"{name} ({x_pt[i]:.3f}, {x_pt[j]:.3f})")
        else:
            ax.scatter(x_pt[i], x_pt[j], s=70, marker=mk, c="none", edgecolors=col, linewidths=1.5,
                       zorder=12, label=f"{name} ({x_pt[i]:.3f}, {x_pt[j]:.3f})")
    ax.set_xlabel(li); ax.set_ylabel(lj)
    ax.set_title(f"{li} vs {lj}")
    ax.set_aspect("equal"); ax.set_xlim(0, 1); ax.set_ylim(0, 1)
sm_s6 = plt.cm.ScalarMappable(norm=_y_norm, cmap="magma")
_handles_s6, _labels_s6 = axes_s6[0].get_legend_handles_labels()
fig_s6.legend(_handles_s6, _labels_s6, loc="lower center", bbox_to_anchor=(0.5, -0.06), ncol=4, framealpha=0.95)
fig_s6.colorbar(sm_s6, ax=axes_s6, shrink=1, label="y")
fig_s6.suptitle("Section 6 — MyBO vs open-source optimizers")
if IF_SHOW_PLOT:
    plt.show()
if IF_EXPORT_PLOT:
    out_path = PLOT_EXPORT_DIR / "function_3_section6_summary.png"
    assert_not_under_initial_data(PLOT_EXPORT_DIR, project_root=repo_root)
    PLOT_EXPORT_DIR.mkdir(parents=True, exist_ok=True)
    fig_s6.savefig(out_path, dpi=150, bbox_inches="tight")
    print("Saved function_3_section6_summary.png")
