# %% [markdown]
# # Function 5: 4D Chemical Process Yield
#
# *Analogy: **Typically unimodal; single peak.** We **maximize** \(y\) (e.g. process yield or conversion efficiency).*
#
#
# ### Characteristics
#
#
# * **4D input**: \((x_1, x_2, x_3, x_4)\) — e.g. temperature, pressure, catalyst, flow-rate parameters in \([0,1]^4\).
#
#
# * **Objective**: Maximize \(y\). Initial data: 20 points, shape (20, 4).
#
#
# * **Strategy**: Same Bayesian optimisation workflow — GP surrogate, EI/PI/UCB acquisition — in 4D; visualisation uses 2D pairwise slices (6 pairs).

# %% [markdown]
# ## 1. Setup and load data
#
# Imports, paths, and load from `observations.csv` (if present) or `initial_data` (read-only). Parameters and flags are in the following cells.

# %%
import sys, copy
import numpy as np
from pathlib import Path
from scipy.stats import norm
import matplotlib.pyplot as plt
from matplotlib import cm

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, ConstantKernel, WhiteKernel
from skopt.acquisition import gaussian_ei, gaussian_pi, gaussian_lcb
from skopt.sampler import Lhs, Sobol

repo_root = Path.cwd() if (Path.cwd() / "src").exists() else Path.cwd().parent
sys.path.insert(0, str(repo_root))
from src.utils.load_challenge_data import (
    load_function_data, load_problem_data_csv, assert_not_under_initial_data,
)
from src.utils.warping import apply_output_warping

np.random.seed(42)

# %%
local_dir       = repo_root / "data" / "problems" / "function_5"
csv_path        = local_dir / "observations.csv"
PLOT_EXPORT_DIR = repo_root / "data" / "results"

# %%
if csv_path.exists():
    X, y = load_problem_data_csv(csv_path)
else:
    X, y = load_function_data(function_id=5)
    y = np.asarray(y, dtype=np.float64).ravel()
try:
    _ = OUTPUT_WARPING
except NameError:
    OUTPUT_WARPING = None
y_orig = np.asarray(y, dtype=np.float64).copy()
y, warp_params, _msg = apply_output_warping(y_orig, mode=OUTPUT_WARPING)
print(_msg)
WARP_LABEL = (warp_params[0] if warp_params else "None")
best_idx  = np.argmax(y)
best_y    = y[best_idx]
best_x_so_far = X[best_idx]

print(f"Loaded {len(y)} obs  |  X {X.shape}  |  best y = {best_y:.4g}  "
      f"at ({best_x_so_far[0]:.4f}, {best_x_so_far[1]:.4f}, {best_x_so_far[2]:.4f}, {best_x_so_far[3]:.4f})")
# Out:
# Output warping: None. GP fits raw y. No transform applied.
# Loaded 25 obs  |  X (25, 4)  |  best y = 7494  at (0.9803, 0.9845, 0.9748, 0.9960)

# %%
CONSTANT_KERNEL_SCALE = 1.0    # output-scale
LENGTH_SCALE          = 1.0    # init length-scale
GP_ALPHA              = 1e-6   # nugget for numerical stability
MATERN_NU             = 1.5    # roughness: 0.5=exp, 1.5=C¹, 2.5=C², ∞=RBF
WHITE_NOISE_LEVEL     = 1e-5   # noise init; raise to 0.01-0.1 if oracle is stochastic
GP_KERNEL             = None   # None → LML auto-select; 'RBF' | 'Matern' | 'RBF + WhiteKernel'

OPTIMIZE_KERNEL       = True   # optimize kernel hyperparameters via MLE
N_RESTARTS_KERNEL     = 20     # 4D: more restarts for LML multimodality
CONSTANT_SCALE_BOUNDS = (1e-3, 1e3)
LENGTH_SCALE_BOUNDS   = (1e-2, 100)
WHITE_NOISE_BOUNDS    = (1e-12, 1e1)

# ==== Output warping (HEBO-inspired) ====
OUTPUT_WARPING = "log"   # y spans ~4 orders (0.1–1e3); log stabilizes GP fit

XI_EI_PI  = 0.1     # ξ for EI/PI: 0.01-0.05 = exploit, 0.1-0.25 = explore (scale relative to y range ~1700)
KAPPA_UCB = 2.0      # κ for UCB: 1-2 = exploit, 3-5 = explore

n_grid_viz = 60         # coarser grid for Section 2 visualisation (scatter + IDW contours)
n_cand     = 2**18      # finer: number of candidates for acquisition maximisation (EI/PI/UCB)
CANDIDATE_SAMPLING_METHOD = "sobol"  # 'lhs' | 'sobol'

USE_ENSEMBLE    = False   # False → use SOLO_STRATEGY only
SOLO_STRATEGY   = "UCB"    # 'EI' | 'PI' | 'UCB'
AGREE_THRESHOLD = 0.15    # max pairwise L2 dist; if exceeded, use centroid
MIN_DIST_THRESHOLD = 0.05  # min L2 distance from any obs; mask acquisition at closer candidates
BOUNDARY_MARGIN = 0     # high-d: keep 0 (curse of dimensionality)

# %%
IF_SHOW_PLOT      = True
IF_EXPORT_PLOT    = True
IF_EXPORT_QUERIES = True
IF_APPEND_DATA    = False

CONTOURF_LEVELS     = 30
CONTOUR_LINE_LEVELS = 11
CONTOUR_LINEWIDTH   = 1.0
CONTOUR_LINESTYLE   = "-"
CONTOUR_ALPHA       = 0.5
SCATTER_EDGE_LW     = 1.5
LEGEND_FONTSIZE     = 9
LEGEND_LOC          = "upper right"
LEGEND_FRAMEALPHA   = 0.95
LEGEND_NCOL         = 7

print('Control flags set')
# Out:
# Control flags set

# %% [markdown]
# ### Progress
#
# Left: \(y\) per query. Right: best \(y\) so far (cumulative max).

# %%
n_obs = len(y)
obs_idx = np.arange(1, n_obs + 1, dtype=float)
best_so_far = np.maximum.accumulate(y)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
ax1.plot(obs_idx, y, 'o-', color='blue', markersize=5, markerfacecolor='w', markeredgecolor='b', markeredgewidth=1.5, label=' y per query')
ax1.set_xlabel('Observation index')
ax1.set_ylabel('y')
ax1.set_title('Output y at each query')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.plot(obs_idx, best_so_far, 'o-', color='red', markersize=5, markerfacecolor='w', markeredgecolor='r', markeredgewidth=1.5, label='Best y so far')
ax2.set_xlabel('Observation index')
ax2.set_ylabel('Best y so far')
ax2.set_title('Cumulative best')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Visualize the points

# %%
pairs = [(0, 1, "x_1", "x_2"), (0, 2, "x_1", "x_3"), (0, 3, "x_1", "x_4"),
         (1, 2, "x_2", "x_3"), (1, 3, "x_2", "x_4"), (2, 3, "x_3", "x_4")]

fig2, axes = plt.subplots(2, 3, figsize=(14, 9), constrained_layout=True)
axes_flat = axes.ravel()
for ax, (i, j, li, lj) in zip(axes_flat, pairs):
    sc = ax.scatter(X[:, i], X[:, j], c=y, s=50, cmap="magma", edgecolors="k", linewidths=SCATTER_EDGE_LW)
    for idx in range(len(y)):
        ax.text(X[idx, i] + 0.02, X[idx, j] + 0.02, str(idx + 1), fontsize=7, zorder=10)
    ax.set_xlabel(li, fontsize=10); ax.set_ylabel(lj, fontsize=10)
    ax.set_title(f"{li} vs {lj}", fontsize=11)
    ax.set_aspect("equal"); ax.set_xlim(0, 1); ax.set_ylim(0, 1)
sm = plt.cm.ScalarMappable(norm=plt.Normalize(y.min(), y.max()), cmap="magma")
sm.set_array(y)
for row in range(2):
    fig2.colorbar(sm, ax=axes[row, :].tolist(), shrink=0.7, label="y").ax.tick_params(labelsize=8)

if IF_EXPORT_PLOT:
    out_dir = PLOT_EXPORT_DIR
    assert_not_under_initial_data(out_dir, project_root=repo_root)
    out_dir.mkdir(parents=True, exist_ok=True)
    fig2.savefig(out_dir / "function_5_observations_2d_pairs.png", dpi=150, bbox_inches="tight")
if IF_SHOW_PLOT:
    plt.show()

n_idw = n_grid_viz
ug_idw = np.linspace(0, 1, n_idw)
Ug_idw, Vg_idw = np.meshgrid(ug_idw, ug_idw)

Y_idw_all = []
for (i, j, li, lj) in pairs:
    grid_2d = np.column_stack([Ug_idw.ravel(), Vg_idw.ravel()])
    obs_2d  = np.column_stack([X[:, i], X[:, j]])
    dist_gx = np.sqrt(((grid_2d[:, None, :] - obs_2d[None, :, :]) ** 2).sum(axis=2)) + 1e-12
    w = 1.0 / (dist_gx ** 2)
    Y_idw_all.append(((w * y[None, :]).sum(axis=1) / w.sum(axis=1)).reshape(Ug_idw.shape))

_idw_min = min(np.nanmin(s) for s in Y_idw_all)
_idw_max = max(np.nanmax(s) for s in Y_idw_all)
if _idw_max <= _idw_min: _idw_max = _idw_min + 1e-10
_idw_levels = np.linspace(_idw_min, _idw_max, CONTOURF_LEVELS)

fig3, axes3 = plt.subplots(2, 3, figsize=(14, 9), constrained_layout=True)
axes3_flat = axes3.ravel()
for ax, (i, j, li, lj), Y_idw in zip(axes3_flat, pairs, Y_idw_all):
    ax.contourf(Ug_idw, Vg_idw, Y_idw, levels=_idw_levels, cmap="magma")
    ax.contour(Ug_idw, Vg_idw, Y_idw, levels=_idw_levels[::max(1, len(_idw_levels)//CONTOUR_LINE_LEVELS)], colors="white", linewidths=CONTOUR_LINEWIDTH, linestyles='-', alpha=CONTOUR_ALPHA)
    ax.scatter(X[:, i], X[:, j], c='red', s=50, edgecolors="k", linewidths=SCATTER_EDGE_LW, zorder=2)
    for idx in range(len(y)):
        ax.text(X[idx, i] + 0.02, X[idx, j] + 0.02, str(idx + 1), fontsize=7, color="white", zorder=10)
    ax.set_xlabel(li, fontsize=10); ax.set_ylabel(lj, fontsize=10)
    ax.set_title(f"{li} vs {lj} (interpolated)", fontsize=11)
    ax.set_aspect("equal"); ax.set_xlim(0, 1); ax.set_ylim(0, 1)
sm3 = plt.cm.ScalarMappable(norm=plt.Normalize(_idw_min, _idw_max), cmap="magma")
sm3.set_array([])
for row in range(2):
    fig3.colorbar(sm3, ax=axes3[row, :].tolist(), shrink=0.7, label="y").ax.tick_params(labelsize=8)

if IF_EXPORT_PLOT:
    fig3.savefig(out_dir / "function_5_observations_2d_pairs_interpolated.png", dpi=150, bbox_inches="tight")
if IF_SHOW_PLOT:
    plt.show()

# %% [markdown]
# ## 3. Suggest next point (Bayesian optimisation)
#
# Fit three GP kernels, select best by log-marginal-likelihood; compute EI, PI, UCB; choose next query (solo or ensemble).

# %% [markdown]
# ### 3.1 Surrogate: GP kernels
#
# - **Gaussian Process (GP)** — We compare three kernel choices; each trades off smoothness, noise handling, and flexibility.
# - **RBF** (squared exponential) — Infinitely smooth; good default.
# - **Matérn (ν=1.5)** — Once-differentiable; more flexible for rough surfaces.
# - **RBF + WhiteKernel** — RBF with explicit observation noise; use when the oracle is stochastic.
#
# Best kernel is chosen by log-marginal-likelihood (or set `GP_KERNEL` manually).

# %%
_sampler = Sobol() if CANDIDATE_SAMPLING_METHOD == "sobol" else Lhs()
candidate_pts = np.array(_sampler.generate([(0.0, 1.0)] * 4, n_cand))

_gp_optimizer = None if not OPTIMIZE_KERNEL else 'fmin_l_bfgs_b'
_gp_n_restarts = N_RESTARTS_KERNEL if OPTIMIZE_KERNEL else 0
kernel_RBF       = ConstantKernel(CONSTANT_KERNEL_SCALE, constant_value_bounds=CONSTANT_SCALE_BOUNDS) * RBF(length_scale=LENGTH_SCALE, length_scale_bounds=LENGTH_SCALE_BOUNDS)
kernel_Matern    = ConstantKernel(CONSTANT_KERNEL_SCALE, constant_value_bounds=CONSTANT_SCALE_BOUNDS) * Matern(length_scale=LENGTH_SCALE, nu=MATERN_NU, length_scale_bounds=LENGTH_SCALE_BOUNDS)
kernel_RBF_noise = ConstantKernel(CONSTANT_KERNEL_SCALE, constant_value_bounds=CONSTANT_SCALE_BOUNDS) * RBF(length_scale=LENGTH_SCALE, length_scale_bounds=LENGTH_SCALE_BOUNDS) + WhiteKernel(noise_level=WHITE_NOISE_LEVEL, noise_level_bounds=WHITE_NOISE_BOUNDS)
gp_RBF       = GaussianProcessRegressor(kernel=kernel_RBF,       alpha=GP_ALPHA, optimizer=_gp_optimizer, n_restarts_optimizer=_gp_n_restarts, normalize_y=True)
gp_Matern    = GaussianProcessRegressor(kernel=kernel_Matern,    alpha=GP_ALPHA, optimizer=_gp_optimizer, n_restarts_optimizer=_gp_n_restarts, normalize_y=True)
gp_RBF_noise = GaussianProcessRegressor(kernel=kernel_RBF_noise, alpha=GP_ALPHA, optimizer=_gp_optimizer, n_restarts_optimizer=_gp_n_restarts, normalize_y=True)
gp_RBF.fit(X, y); gp_Matern.fit(X, y); gp_RBF_noise.fit(X, y)
print(f"Kernel hyperparameters: {'optimized (MLE)' if OPTIMIZE_KERNEL else 'fixed (no optimization)'}")
mu_cand_RBF, sigma_cand_RBF = gp_RBF.predict(candidate_pts, return_std=True)
mu_cand_Matern, sigma_cand_Matern = gp_Matern.predict(candidate_pts, return_std=True)
mu_cand_RBF_noise, sigma_cand_RBF_noise = gp_RBF_noise.predict(candidate_pts, return_std=True)
gp_neg_RBF = copy.deepcopy(gp_RBF); gp_neg_Matern = copy.deepcopy(gp_Matern); gp_neg_RBF_noise = copy.deepcopy(gp_RBF_noise)
gp_neg_RBF.fit(X, -y); gp_neg_Matern.fit(X, -y); gp_neg_RBF_noise.fit(X, -y)
print("GP RBF:", gp_RBF.kernel_)
# Out:
# Kernel hyperparameters: optimized (MLE)
# GP RBF: 1.69**2 * RBF(length_scale=0.665)

# %%
gps = [
    (gp_RBF,       gp_neg_RBF,       "RBF"),
    (gp_Matern,    gp_neg_Matern,    "Matérn (ν=1.5)"),
    (gp_RBF_noise, gp_neg_RBF_noise, "RBF + WhiteKernel"),
]
CANONICAL_NAMES = ["RBF", "Matérn (ν=1.5)", "RBF + WhiteKernel"]
KERNEL_ALIASES = {
    "rbf": "RBF", "matern": "Matérn (ν=1.5)", "matérn (ν=1.5)": "Matérn (ν=1.5)",
    "matern (v=1.5)": "Matérn (ν=1.5)", "rbf + whitekernel": "RBF + WhiteKernel",
    "rbf+whitekernel": "RBF + WhiteKernel", "rbf + white": "RBF + WhiteKernel", "white": "RBF + WhiteKernel",
}

if GP_KERNEL is None or str(GP_KERNEL).strip().lower() in ("none", "auto", ""):
    lml = {name: gp.log_marginal_likelihood_value_ for gp, _, name in gps}
    best_name = max(lml, key=lml.get)
    print("LML scores:", {k: f"{v:.2f}" for k, v in lml.items()})
    print(f"Auto-selected kernel: {best_name} (highest LML)")
else:
    key = str(GP_KERNEL).strip().lower()
    best_name = KERNEL_ALIASES.get(key, GP_KERNEL)
    if best_name not in CANONICAL_NAMES:
        raise ValueError(f"Unknown GP_KERNEL='{GP_KERNEL}'. Use one of {CANONICAL_NAMES}")
    print(f"Manual kernel override: {best_name}")

is_rbf    = best_name == "RBF"
is_matern = best_name == "Matérn (ν=1.5)"
is_rbf_w  = best_name == "RBF + WhiteKernel"

best_gp     = gp_RBF if is_rbf else (gp_Matern if is_matern else gp_RBF_noise)
best_gp_neg = gp_neg_RBF if is_rbf else (gp_neg_Matern if is_matern else gp_neg_RBF_noise)
print(f"OPTIMIZE_KERNEL = {OPTIMIZE_KERNEL}")
# Out:
# LML scores: {'RBF': '-16.13', 'Matérn (ν=1.5)': '-13.90', 'RBF + WhiteKernel': '-11.16'}
# Auto-selected kernel: RBF + WhiteKernel (highest LML)
# OPTIMIZE_KERNEL = True

# %%
n_slice = 50
ug = np.linspace(0, 1, n_slice)
Ug, Vg = np.meshgrid(ug, ug)
med = [np.median(X[:, k]) for k in range(4)]
slices_info = []
for ia, ib, la, lb in pairs:
    other = [k for k in range(4) if k not in (ia, ib)]
    slice_pts = np.zeros((Ug.size, 4))
    slice_pts[:, ia] = Ug.ravel()
    slice_pts[:, ib] = Vg.ravel()
    for k in other:
        slice_pts[:, k] = med[k]
    held = ", ".join(f"x_{k+1}={med[k]:.2f}" for k in other)
    slices_info.append((slice_pts, ia, ib, la, lb, held))

fig, axes = plt.subplots(6, 2, figsize=(10, 24))
for row, (slice_pts, ia, ib, la, lb, held) in enumerate(slices_info):
    for gp_obj, _, gp_name in gps:
        if gp_name != best_name:
            continue
        mu_s, sig_s = gp_obj.predict(slice_pts, return_std=True)
        mu_s = mu_s.reshape(Ug.shape); sig_s = sig_s.reshape(Ug.shape)
    ax_mu, ax_sig = axes[row, 0], axes[row, 1]
    _mu_min, _mu_max = np.nanmin(mu_s), np.nanmax(mu_s)
    if _mu_max <= _mu_min: _mu_max = _mu_min + 1e-10
    lev_mu = np.linspace(_mu_min, _mu_max, CONTOURF_LEVELS)
    cf1 = ax_mu.contourf(Ug, Vg, mu_s, levels=lev_mu, cmap="viridis")
    ax_mu.contour(Ug, Vg, mu_s, levels=np.linspace(_mu_min, _mu_max, CONTOUR_LINE_LEVELS),
                  colors="k", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig.colorbar(cf1, ax=ax_mu).set_label("μ(x)", fontsize=10)
    ax_mu.scatter(X[:, ia], X[:, ib], c="red", s=60, edgecolors="k", zorder=2, linewidths=1.5)
    ax_mu.set_xlabel(la, fontsize=10); ax_mu.set_ylabel(lb, fontsize=10)
    ax_mu.set_title(f"{best_name} — mean ({held})", fontsize=10)
    ax_mu.set_aspect("equal"); ax_mu.set_xlim(0, 1); ax_mu.set_ylim(0, 1)

    _sig_min, _sig_max = np.nanmin(sig_s), np.nanmax(sig_s)
    if _sig_max <= _sig_min: _sig_max = _sig_min + 1e-10
    lev_sig = np.linspace(_sig_min, _sig_max, CONTOURF_LEVELS)
    cf2 = ax_sig.contourf(Ug, Vg, sig_s, levels=lev_sig, cmap="plasma")
    ax_sig.contour(Ug, Vg, sig_s, levels=np.linspace(_sig_min, _sig_max, CONTOUR_LINE_LEVELS),
                   colors="b", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig.colorbar(cf2, ax=ax_sig).set_label("σ(x)", fontsize=10)
    ax_sig.scatter(X[:, ia], X[:, ib], c="red", s=60, edgecolors="k", zorder=2, linewidths=1.5)
    ax_sig.set_xlabel(la, fontsize=10); ax_sig.set_ylabel(lb, fontsize=10)
    ax_sig.set_title(f"{best_name} — std ({held})", fontsize=10)
    ax_sig.set_aspect("equal"); ax_sig.set_xlim(0, 1); ax_sig.set_ylim(0, 1)

fig.suptitle(f"GP surrogate: posterior mean (μ) and uncertainty (σ)  [{best_name}]  |  warping: {WARP_LABEL}", fontsize=13, y=1.005)
fig.tight_layout()
if IF_EXPORT_PLOT:
    out_dir = PLOT_EXPORT_DIR; out_dir.mkdir(parents=True, exist_ok=True)
    fig.savefig(out_dir / "function_5_gp_slices.png", dpi=150, bbox_inches="tight")
if IF_SHOW_PLOT:
    plt.show()

# %% [markdown]
# ### 3.2 Acquisition functions* Expected Improvement (EI)* Upper Confidence Bound (UCB)* Probability of Improvement (PI)

# %%
y_best = best_y

EI_RBF  = gaussian_ei(candidate_pts, gp_neg_RBF, y_opt=-y_best, xi=XI_EI_PI)
PI_RBF  = gaussian_pi(candidate_pts, gp_neg_RBF, y_opt=-y_best, xi=XI_EI_PI)
LCB_RBF = gaussian_lcb(candidate_pts, gp_neg_RBF, kappa=KAPPA_UCB)
EI_Matern  = gaussian_ei(candidate_pts, gp_neg_Matern, y_opt=-y_best, xi=XI_EI_PI)
PI_Matern  = gaussian_pi(candidate_pts, gp_neg_Matern, y_opt=-y_best, xi=XI_EI_PI)
LCB_Matern = gaussian_lcb(candidate_pts, gp_neg_Matern, kappa=KAPPA_UCB)

EI_RBF_noise  = gaussian_ei(candidate_pts, gp_neg_RBF_noise, y_opt=-y_best, xi=XI_EI_PI)
PI_RBF_noise  = gaussian_pi(candidate_pts, gp_neg_RBF_noise, y_opt=-y_best, xi=XI_EI_PI)
LCB_RBF_noise = gaussian_lcb(candidate_pts, gp_neg_RBF_noise, kappa=KAPPA_UCB)

# Mask candidates too close to existing observations (avoid re-evaluating)
min_dist_cand = np.min(np.sqrt(((candidate_pts[:, None, :] - X[None, :, :]) ** 2).sum(axis=2)), axis=1)
next_x_high_dist = np.clip(np.asarray(candidate_pts[np.argmax(min_dist_cand)]).ravel(), 0.0, 0.999999)
too_close = min_dist_cand < MIN_DIST_THRESHOLD
try: BOUNDARY_MARGIN
except NameError: BOUNDARY_MARGIN = 0
# Optional: mask candidates near domain boundaries (low-d only; set BOUNDARY_MARGIN=0 for high-d)
near_boundary = np.any((candidate_pts <= BOUNDARY_MARGIN) | (candidate_pts >= 1.0 - BOUNDARY_MARGIN), axis=1) if BOUNDARY_MARGIN > 0 else np.zeros(len(candidate_pts), dtype=bool)
masked = too_close | near_boundary
EI_RBF[masked] = EI_Matern[masked] = EI_RBF_noise[masked] = -np.inf
PI_RBF[masked] = PI_Matern[masked] = PI_RBF_noise[masked] = -np.inf
LCB_RBF[masked] = LCB_Matern[masked] = LCB_RBF_noise[masked] = np.inf

def _pick(acq_val, maximize, fallback):
    idx = np.argmax(acq_val) if maximize else np.argmin(acq_val)
    return np.asarray(fallback).ravel() if masked[idx] else candidate_pts[idx]

x_best_EI_RBF  = _pick(EI_RBF, True, next_x_high_dist)
x_best_PI_RBF  = _pick(PI_RBF, True, next_x_high_dist)
x_best_UCB_RBF = _pick(LCB_RBF, False, next_x_high_dist)
x_best_EI_Matern  = _pick(EI_Matern, True, next_x_high_dist)
x_best_PI_Matern  = _pick(PI_Matern, True, next_x_high_dist)
x_best_UCB_Matern = _pick(LCB_Matern, False, next_x_high_dist)
x_best_EI_RBF_noise  = _pick(EI_RBF_noise, True, next_x_high_dist)
x_best_PI_RBF_noise  = _pick(PI_RBF_noise, True, next_x_high_dist)
x_best_UCB_RBF_noise = _pick(LCB_RBF_noise, False, next_x_high_dist)

x_best_EI  = x_best_EI_RBF  if is_rbf else (x_best_EI_Matern  if is_matern else x_best_EI_RBF_noise)
x_best_PI  = x_best_PI_RBF  if is_rbf else (x_best_PI_Matern  if is_matern else x_best_PI_RBF_noise)
x_best_UCB = x_best_UCB_RBF if is_rbf else (x_best_UCB_Matern if is_matern else x_best_UCB_RBF_noise)

print(f"Best kernel: {best_name}")
print(f"  EI  argmax: ({x_best_EI[0]:.4f}, {x_best_EI[1]:.4f}, {x_best_EI[2]:.4f}, {x_best_EI[3]:.4f})")
print(f"  PI  argmax: ({x_best_PI[0]:.4f}, {x_best_PI[1]:.4f}, {x_best_PI[2]:.4f}, {x_best_PI[3]:.4f})")
print(f"  UCB argmax: ({x_best_UCB[0]:.4f}, {x_best_UCB[1]:.4f}, {x_best_UCB[2]:.4f}, {x_best_UCB[3]:.4f})")
# Out:
# Best kernel: RBF + WhiteKernel
#   EI  argmax: (0.9917, 0.9898, 0.9901, 0.9222)
#   PI  argmax: (0.9917, 0.9898, 0.9901, 0.9222)
#   UCB argmax: (0.9917, 0.9898, 0.9901, 0.9222)

# %%
rng = np.random.default_rng(42)
best_x = best_x_so_far.copy()
next_x_exploit = np.clip(best_x + rng.uniform(-0.1, 0.1, size=4), 0, 1)
next_x_explore = rng.uniform(0, 1, size=4)
print("Exploit:  ", next_x_exploit)
print("Explore:  ", next_x_explore)
# Out:
# Exploit:   [1.         0.97225769 1.         1.        ]
# Explore:   [0.09417735 0.97562235 0.7611397  0.78606431]

# %% [markdown]
# ### 3.3 Acquisition surfaces
#
# EI/PI/UCB are evaluated on `candidate_pts` (no 2D contour for 4D). **Section 5** shows the suggested next query and EI/PI/UCB argmax locations on GP mean/std slices.

# %% [markdown]
# ### Pairwise distances between suggestions (small = agree)Small values mean two strategies agree; large values mean the next query depends on strategy choice.

# %%
names = ['EI', 'UCB', 'PI']
pts = [np.asarray(x).ravel() for x in [x_best_EI, x_best_UCB, x_best_PI]]
n_pts = len(pts)
dists = np.zeros((n_pts, n_pts))
for i in range(n_pts):
    for j in range(n_pts):
        dists[i, j] = np.linalg.norm(pts[i] - pts[j])
for i in range(n_pts):
    for j in range(i + 1, n_pts):
        print(f"  {names[i]} vs {names[j]}: {dists[i, j]:.4f}")
max_d_3 = max(np.linalg.norm(pts[0]-pts[1]), np.linalg.norm(pts[0]-pts[2]), np.linalg.norm(pts[1]-pts[2]))
if max_d_3 < AGREE_THRESHOLD:
    print(f"\n>>> EI/PI/UCB agree (max pairwise dist = {max_d_3:.4f} < {AGREE_THRESHOLD}).")
else:
    print(f"\n>>> EI/PI/UCB differ (max dist = {max_d_3:.4f}); ensemble would use centroid.")
# Out:
#   EI vs UCB: 0.0000
#   EI vs PI: 0.0000
#   UCB vs PI: 0.0000
#
# >>> EI/PI/UCB agree (max pairwise dist = 0.0000 < 0.15).

# %% [markdown]
# ## 4. Select next query
#
# - **Ensemble mode** (`USE_ENSEMBLE=True`): if EI, PI, UCB agree (pairwise distance &lt; `AGREE_THRESHOLD`) → use EI argmax; else → use centroid.
# - **Solo mode** (`USE_ENSEMBLE=False`): use `SOLO_STRATEGY` (EI / PI / UCB).
#
# See `docs_private/ENSEMBLE_ACQUISITION_GUIDE.md`.

# %%
x_EI  = np.asarray(x_best_EI).ravel()
x_PI  = np.asarray(x_best_PI).ravel()
x_UCB = np.asarray(x_best_UCB).ravel()
pts = np.array([x_EI, x_PI, x_UCB])
d12 = np.linalg.norm(pts[0] - pts[1])
d13 = np.linalg.norm(pts[0] - pts[2])
d23 = np.linalg.norm(pts[1] - pts[2])
max_d = max(d12, d13, d23)

_solo_map = {"EI": x_EI, "PI": x_PI, "UCB": x_UCB}
next_x_no_ens = np.clip(_solo_map.get(SOLO_STRATEGY, x_EI).copy(), 0.0, 0.999999)
next_x_with_ens = np.clip(np.mean(pts, axis=0), 0.0, 0.999999) if max_d >= AGREE_THRESHOLD else np.clip(x_EI.copy(), 0.0, 0.999999)

fmt = lambda v: ", ".join(f"{x:.4f}" for x in v)
print(f"Without ensemble ({SOLO_STRATEGY}):  x = ({fmt(next_x_no_ens)})")
print(f"With ensemble: EI=({fmt(x_EI)}), PI=({fmt(x_PI)}), UCB=({fmt(x_UCB)}) → max_dist={max_d:.4f}")
print(f"  → {'centroid' if max_d >= AGREE_THRESHOLD else 'all agree, EI'} = ({fmt(next_x_with_ens)})")

next_x = next_x_with_ens if USE_ENSEMBLE else next_x_no_ens

# Proximity check: only replace with fallback for near-duplicates.
DUPLICATE_THRESHOLD = 1e-3
dist_to_obs = np.sqrt(((X - next_x) ** 2).sum(axis=1))
nearest_idx  = np.argmin(dist_to_obs)
nearest_dist = dist_to_obs[nearest_idx]
if nearest_dist < DUPLICATE_THRESHOLD:
    print(f"⚠ Proposed point is duplicate (dist={nearest_dist:.2e} to obs #{nearest_idx+1}); using high-dist fallback.")
    next_x = next_x_high_dist
elif nearest_dist < MIN_DIST_THRESHOLD:
    print(f"  (Proposed point is {nearest_dist:.4f} from obs #{nearest_idx+1} — keeping it.)")

_strat = 'ensemble' if USE_ENSEMBLE else SOLO_STRATEGY
print(f"Next query | kernel: {best_name} | strategy: {_strat} | xi={XI_EI_PI}")
print(f"  x = ({fmt(next_x)})")
print(f"  Nearest existing obs: #{nearest_idx+1} at dist={nearest_dist:.4f}")
print(f"  Current best y = {best_y:.4g} at ({fmt(best_x_so_far)})")
# Out:
# Without ensemble (UCB):  x = (0.9917, 0.9898, 0.9901, 0.9222)
# With ensemble: EI=(0.9917, 0.9898, 0.9901, 0.9222), PI=(0.9917, 0.9898, 0.9901, 0.9222), UCB=(0.9917, 0.9898, 0.9901, 0.9222) → max_dist=0.0000
#   → all agree, EI = (0.9917, 0.9898, 0.9901, 0.9222)
# Next query | kernel: RBF + WhiteKernel | strategy: UCB | xi=0.1
#   x = (0.9917, 0.9898, 0.9901, 0.9222)
#   Nearest existing obs: #25 at dist=0.0764
#   Current best y = 7494 at (0.9803, 0.9845, 0.9748, 0.9960)

# %% [markdown]
# ## 5. Illustrate the locations on the proposed query

# %%
try:
    _ = next_x
except NameError:
    _ei = gaussian_ei(candidate_pts, best_gp_neg, y_opt=-y_best, xi=XI_EI_PI)
    next_x = np.clip(np.asarray(candidate_pts[np.argmax(_ei)]).ravel(), 0.0, 0.999999)

X_best_combined = np.array([x_best_EI, x_best_PI, x_best_UCB])
labels_combined = ['EI', 'PI', 'UCB']
colors_combined = plt.cm.cool(np.linspace(0, 1, len(X_best_combined)))
markers_size = [50, 100, 150]
next_x_plot = np.asarray(next_x).ravel()

n_acq_slice = 50
ug_acq = np.linspace(0, 1, n_acq_slice)
Ug_acq, Vg_acq = np.meshgrid(ug_acq, ug_acq)
med_acq = [np.median(X[:, k]) for k in range(4)]

slices_acq = []
for ia, ib, la, lb in pairs:
    other = [k for k in range(4) if k not in (ia, ib)]
    slice_pts = np.zeros((Ug_acq.size, 4))
    slice_pts[:, ia] = Ug_acq.ravel()
    slice_pts[:, ib] = Vg_acq.ravel()
    for k in other:
        slice_pts[:, k] = med_acq[k]
    held = ", ".join(f"x_{k+1}={med_acq[k]:.2f}" for k in other)
    slices_acq.append((slice_pts, ia, ib, la, lb, held))

fig2, axes = plt.subplots(6, 2, figsize=(10, 24))
for row, (slice_pts, ia, ib, la, lb, held) in enumerate(slices_acq):
    mu_s, sig_s = best_gp.predict(slice_pts, return_std=True)
    mu_s = mu_s.reshape(Ug_acq.shape); sig_s = sig_s.reshape(Ug_acq.shape)
    ax_mu, ax_sig = axes[row, 0], axes[row, 1]

    _mu_min, _mu_max = np.nanmin(mu_s), np.nanmax(mu_s)
    if _mu_max <= _mu_min: _mu_max = _mu_min + 1e-10
    lev_mu = np.linspace(_mu_min, _mu_max, CONTOURF_LEVELS)
    cf1 = ax_mu.contourf(Ug_acq, Vg_acq, mu_s, levels=lev_mu, cmap="viridis")
    ax_mu.contour(Ug_acq, Vg_acq, mu_s, levels=np.linspace(_mu_min, _mu_max, CONTOUR_LINE_LEVELS),
                  colors="k", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig2.colorbar(cf1, ax=ax_mu).set_label("μ(x)", fontsize=10)
    ax_mu.scatter(X[:, ia], X[:, ib], c="white", s=60, edgecolors="r", zorder=5, linewidths=1.5, label="Observations")
    ax_mu.scatter(best_x_so_far[ia], best_x_so_far[ib], s=500, marker="+", c="blue", linewidths=1.5, zorder=8, label="Best obs")
    for pt, lbl, col, size in zip(X_best_combined, labels_combined, colors_combined, markers_size):
        ax_mu.scatter(pt[ia], pt[ib], s=size, marker="s", c='none', edgecolors=[col], linewidths=2.0, alpha=0.95, zorder=10, label=lbl)
        ax_mu.annotate(lbl, (pt[ia], pt[ib]), xytext=(5, 5), textcoords="offset points", fontsize=9, zorder=11)
    ax_mu.scatter(next_x_plot[ia], next_x_plot[ib], facecolors="none", s=200, marker="s", edgecolors="red", linewidths=2, zorder=12, label="Proposed query")
    ax_mu.axvline(next_x_plot[ia], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_mu.axhline(next_x_plot[ib], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_mu.set_xlabel(la, fontsize=10); ax_mu.set_ylabel(lb, fontsize=10)
    ax_mu.set_title(f"Mean — {best_name} ({held})", fontsize=10)
    ax_mu.set_aspect("equal"); ax_mu.set_xlim(0, 1); ax_mu.set_ylim(0, 1)

    _sig_min, _sig_max = np.nanmin(sig_s), np.nanmax(sig_s)
    if _sig_max <= _sig_min: _sig_max = _sig_min + 1e-10
    lev_sig = np.linspace(_sig_min, _sig_max, CONTOURF_LEVELS)
    cf2 = ax_sig.contourf(Ug_acq, Vg_acq, sig_s, levels=lev_sig, cmap="plasma")
    ax_sig.contour(Ug_acq, Vg_acq, sig_s, levels=np.linspace(_sig_min, _sig_max, CONTOUR_LINE_LEVELS),
                   colors="b", linewidths=CONTOUR_LINEWIDTH, alpha=CONTOUR_ALPHA, linestyles=CONTOUR_LINESTYLE)
    fig2.colorbar(cf2, ax=ax_sig).set_label("σ(x)", fontsize=10)
    ax_sig.scatter(X[:, ia], X[:, ib], c="white", s=60, edgecolors="r", zorder=5, linewidths=1.5)
    ax_sig.scatter(best_x_so_far[ia], best_x_so_far[ib], s=500, marker="+", c="blue", linewidths=1.5, zorder=8)
    ax_sig.scatter(next_x_plot[ia], next_x_plot[ib], facecolors="none", s=200, marker="s", edgecolors="red", linewidths=2, zorder=12)
    ax_sig.axvline(next_x_plot[ia], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_sig.axhline(next_x_plot[ib], color="r", linestyle="--", linewidth=1.5, alpha=0.9, zorder=6)
    ax_sig.set_xlabel(la, fontsize=10); ax_sig.set_ylabel(lb, fontsize=10)
    ax_sig.set_title(f"Std — {best_name} ({held})", fontsize=10)
    ax_sig.set_aspect("equal"); ax_sig.set_xlim(0, 1); ax_sig.set_ylim(0, 1)

handles, lbls = axes[0, 0].get_legend_handles_labels()
fig2.legend(handles, lbls, loc="lower center", bbox_to_anchor=(0.5, -0.02),
            ncol=LEGEND_NCOL, fontsize=LEGEND_FONTSIZE, frameon=True, framealpha=LEGEND_FRAMEALPHA)
_strat_label = ("ensemble — centroid" if (USE_ENSEMBLE and max_d >= AGREE_THRESHOLD)
                else "ensemble — EI (agreed)" if USE_ENSEMBLE
                else SOLO_STRATEGY)
fmt_x = ", ".join(f"{v:.4f}" for v in next_x)
fig2.tight_layout(rect=[0, 0, 1, 0.96])
fig2.suptitle(f"Proposed query: x = ({fmt_x})  |  kernel: {best_name}  |  strategy: {_strat_label}  |  warping: {WARP_LABEL}", fontsize=11, y=0.98)

if IF_SHOW_PLOT:
    plt.show()
if IF_EXPORT_PLOT:
    out_dir = PLOT_EXPORT_DIR; out_dir.mkdir(parents=True, exist_ok=True)
    fig2.savefig(out_dir / "function_5_acquisition_points_2d_pairs.png", dpi=150, bbox_inches="tight")

# %%
if IF_EXPORT_QUERIES:
    next_x_clip = np.clip(np.asarray(next_x, dtype=np.float64).ravel(), 0.0, 0.999999)
    portal_str = "-".join(f"{v:.6f}" for v in next_x_clip)
    out_dir = repo_root / "data" / "submissions" / "function_5"
    assert_not_under_initial_data(out_dir, project_root=repo_root)
    out_dir.mkdir(parents=True, exist_ok=True)
    np.save(out_dir / "next_input.npy", next_x_clip)
    (out_dir / "next_input_portal.txt").write_text(portal_str)
    print("Saved. Portal string:", portal_str)
else:
    print("IF_EXPORT_QUERIES=False; not saved.")
# Out:
# Saved. Portal string: 0.991716-0.989804-0.990131-0.922233

# %% [markdown]
# ## 6. MyBO vs Open Source Optimizers
#
# Compare **MyBO** (this notebook's EI/ensemble pipeline), **Optuna**, **TuRBO**, and **GA** on the same data. Summary: 6 pairwise projections with observations coloured by y and each solver's suggested point overlaid.

# %%
# MyBO = this notebook's next_x (Section 4). Optuna, TuRBO, GA = external solver wrappers.
# TuRBO requires BoTorch: pip install botorch (if you see "TuRBO skipped").
bounds_01 = [(0.0, 1.0)] * 4
suggestions = [("MyBO", np.asarray(next_x).ravel())]

def _try_suggest(name, mod_path, kwargs):
    try:
        mod = __import__(mod_path, fromlist=["suggest"])
        x_pt = np.asarray(mod.suggest(X, y, **kwargs)).ravel()
        return (name, x_pt)
    except Exception as e:
        print(f"{name} skipped — {e}")
        return None

for name, mod, kw in [
    ("Optuna", "src.optimizers.wrappers.optuna_solver", {"bounds": bounds_01, "function_id": 5, "seed": 42}),
    ("TuRBO",  "src.optimizers.wrappers.turbo_solver",  {"bounds": bounds_01, "function_id": 5, "seed": 43}),
    ("GA",     "src.optimizers.wrappers.ga_solver",     {"bounds": bounds_01, "function_id": 5, "seed": 44}),
]:
    r = _try_suggest(name, mod, kw)
    if r is not None:
        suggestions.append(r)

_SOLVER_STYLE = {"MyBO": ("s", "red"), "Optuna": ("o", "blue"), "TuRBO": ("^", "green"), "GA": ("D", "magenta")}
_FALLBACK_STYLES = [("P", "orange"), ("*", "cyan"), ("h", "lime")]

pairs = [(0, 1, "x_1", "x_2"), (0, 2, "x_1", "x_3"), (0, 3, "x_1", "x_4"),
         (1, 2, "x_2", "x_3"), (1, 3, "x_2", "x_4"), (2, 3, "x_3", "x_4")]
fig_s6, axes_s6 = plt.subplots(2, 3, figsize=(14, 9), constrained_layout=True)
axes_flat = axes_s6.ravel()
_y_norm = plt.Normalize(float(np.min(y)), float(np.max(y)))
for ax, (i, j, li, lj) in zip(axes_flat, pairs):
    ax.scatter(X[:, i], X[:, j], c=y, s=50, cmap="magma", norm=_y_norm,
               edgecolors="gray", linewidths=SCATTER_EDGE_LW, zorder=5)
    ax.scatter(best_x_so_far[i], best_x_so_far[j], s=250, marker="+", c="blue", linewidths=2, zorder=8, label="Best obs")
    for idx, (name, x_pt) in enumerate(suggestions):
        mk, col = _SOLVER_STYLE.get(name, _FALLBACK_STYLES[min(idx, len(_FALLBACK_STYLES)-1)])
        if mk in ("x", "+"):
            ax.scatter(x_pt[i], x_pt[j], s=70, marker=mk, c=col, linewidths=2, zorder=12, label=f"{name}")
        else:
            ax.scatter(x_pt[i], x_pt[j], s=70, marker=mk, c="none", edgecolors=col, linewidths=1.5, zorder=12, label=f"{name}")
    ax.set_xlabel(li); ax.set_ylabel(lj); ax.set_title(f"{li} vs {lj}")
    ax.set_aspect("equal"); ax.set_xlim(0, 1); ax.set_ylim(0, 1)
    ax.legend(loc="upper left", fontsize=7, ncol=3)
fig_s6.colorbar(plt.cm.ScalarMappable(norm=_y_norm, cmap="magma"), ax=axes_flat, shrink=0.5, label="y")
fig_s6.suptitle("§6  MyBO vs Open Source Optimizers", fontsize=12, fontweight="bold")
if IF_SHOW_PLOT:
    plt.show()
if IF_EXPORT_PLOT:
    out_path = PLOT_EXPORT_DIR / "function_5_section6_summary.png"
    out_path.parent.mkdir(parents=True, exist_ok=True)
    fig_s6.savefig(out_path, dpi=150, bbox_inches="tight")
    print("Saved function_5_section6_summary.png")
# Out:
# [I 2026-03-17 20:31:02,961] A new study created in memory with name: no-name-21f62c54-3408-4122-9b3f-6bc3d02694ad
# /opt/homebrew/lib/python3.14/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /opt/homebrew/lib/python3.14/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-10. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %% [markdown]
# ## 7. Append new feedback (after portal returns)
#
# After you submit and receive **(x, y)** from the portal for Function 5:
#
# 1. Set `IF_APPEND_DATA = True` in the flags cell.
# 2. Paste the returned \(x\) and \(y\) into the cell below.
# 3. Run the cell — it appends to `data/problems/function_5/observations.csv`.
#
# The next run from the top will load initial data plus all appended points.

# %%
if IF_APPEND_DATA:
    from src.utils.load_challenge_data import save_problem_data_csv
    new_x = np.array([0.5, 0.5, 0.5, 0.5])  # paste portal x values here
    new_y = np.array([0.0])                   # paste portal y value here
    X = np.vstack([X, new_x.reshape(1, 4)])
    y = np.append(y.ravel(), new_y.ravel())
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    assert_not_under_initial_data(csv_path.parent, project_root=repo_root)
    save_problem_data_csv(csv_path, X, y)
    print(f"Appended (x={new_x}, y={new_y[0]:.6f}) → {csv_path}")
else:
    print("IF_APPEND_DATA is False; nothing appended.")
# Out:
# IF_APPEND_DATA is False; nothing appended.
